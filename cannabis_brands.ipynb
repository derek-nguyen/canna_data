# %%
import csv
from bs4 import BeautifulSoup
import requests

# %%
brands = requests.get('https://www.leafly.com/brands')
brands.content
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %% [markdown]
# # All Links for Blue Dream

# %%
soup = BeautifulSoup(brands.content, 'html.parser')
print (soup.prettify())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# links = soup.find_all('a')
# for link in link:
#     print (link.get('href'))

# %% [markdown]
# # All brand name

# %%
brand_name_data = soup.find_all('span',{'class':"item-name"})
# print (brand_name_data)

# %%
for item in brand_name_data:
    print (item.text)
# Out:
# A2FLY
# Aardvark Extracts
# Abattis Bioceuticals Corp
# Ablis-Ablis Drink
# Ablis Sparkling Green
# Above Top Shelf
# Absolute Cannabis Seeds
# Absolute Security and Personal Protection
# Absolute Terps
# AbsoluteXtracts
# Absorb CBD
# Abundant
# Accannadations LLC
# Accelerated Growth Solutions (AGS)
# Access Marijuana RX
# Aces Extracts
# ACESO Sprays
# ACME Elixirs
# AcquiFlow
# AcroVape
# ACT Laboratories
# ACW Supply
# Adam Equipment
# Adams
# Adem and Leaves                                            - Embroidered Apparel and other items -
# Adherence Colorado
# Adilas
# Advanced Canna Technologies
# Advanced Extracts
# Advanced Seeds
# Aerobiological Engineering
# AeroInhaler
# A+ Extract
# Aficionado
# AgDynamix
# Agency For Higher
# Age Old Organics
# A.G.I.M
# Agricor Laboratories
# Agrijuana
# Agrisani
# AgriScience Labs
# Agris Farms
# Agro Mechanix
# AIM High Co
# Aims Horticulture
# Airistech
# AirVape
# Alaf Farms
# ALAIR Vaporizers
# Alaskan Blooms
# ...

# %%
# number of brands
print(type(brand_name_data))
print(len(brand_name_data))
# Out:
# <class 'bs4.element.ResultSet'>
# 4170
