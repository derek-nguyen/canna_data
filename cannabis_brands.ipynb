# %%
import pandas as pd
import csv
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.leafly.com/brands'
brands = requests.get(url)
print(brands.text[:500])
# brands.content
# Out:
# <!DOCTYPE html>
# <html data-ng-controller="MainCtrl as main" data-ng-class="{'navigation-open' : main.showNavigation}" class="leafly2016">
# <head>
#     <title>Marijuana Brands - Leafly</title>
#     <script type="text/javascript">var _sf_startpt = (new Date()).getTime();</script>
#     <meta charset="utf-8" /><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"3ae8b694d3","applicationID":"20106270","transact

# %%
soup = BeautifulSoup(brands.content, 'html.parser')
# print (soup.prettify())

# %%
# links = soup.find_all('a')
# for link in links:
#     print (link.get('href'))

# %% [markdown]
# # All Brand Name (leafly)

# %%
brand_containers = soup.find_all('a',{'class':'item'})
print(type(brand_containers))
print(len(brand_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 4172

# %%
# showing only one brand
first_brand = brand_containers[1]
first_brand
# Out:
# <a class="item" gtm-push="{'business.slug': 'aardvark-extracts', 'business.name': 'Aardvark Extracts'}" href="/brands/aardvark-extracts">
# <div class="item-thumbnail item-thumbnail-square">
# <div class="item-thumbnail-centered">
# <img alt="Aardvark Extracts" class="b-lazy" data-src="https://ddd33q3967xhi.cloudfront.net/eP4cjMNMzN_HFoVZ3RFiyoaho2w=/fit-in/150x150/filters:fill(ffffff%2ctrue)/https%3a%2f%2fs3.amazonaws.com%2fleafly-s3%2fbrands%2flogos%2fABdrxmJ6RQeQK4Tg68zh_sr7MydBY.jpg" data-srcset="https://ddd33q3967xhi.cloudfront.net/eP4cjMNMzN_HFoVZ3RFiyoaho2w=/fit-in/150x150/filters:fill(ffffff%2ctrue)/https%3a%2f%2fs3.amazonaws.com%2fleafly-s3%2fbrands%2flogos%2fABdrxmJ6RQeQK4Tg68zh_sr7MydBY.jpg 150w,
#                                                                           https://ddd33q3967xhi.cloudfront.net/2yLImXjczAujJ5HW3t8I-ozp1ss=/fit-in/300x300/filters:fill(ffffff%2ctrue)/https%3a%2f%2fs3.amazonaws.com%2fleafly-s3%2fbrands%2flogos%2fABdrxmJ6RQeQK4Tg68zh_sr7MydBY.jpg 300w" sizes="(min-width: 1025px) 140px, 20vw" src="/content/images/brands/brand-placeholder.svg">
# </img></div>
# </div>
# <span class="item-name">Aardvark Extracts</span>
# </a>

# %%
first_name = first_brand.span.text
first_name
# Out:
# 'Aardvark Extracts'

# %%
# brand logos

first_logo = first_brand.find('img', attrs = {'class': 'b-lazy'})
first_logo['data-src']
# Out:
# 'https://ddd33q3967xhi.cloudfront.net/eP4cjMNMzN_HFoVZ3RFiyoaho2w=/fit-in/150x150/filters:fill(ffffff%2ctrue)/https%3a%2f%2fs3.amazonaws.com%2fleafly-s3%2fbrands%2flogos%2fABdrxmJ6RQeQK4Tg68zh_sr7MydBY.jpg'

# %%
# lists to store the scraped data in

names = []
logo_links = []

# %%
# extract data from individual brand containers
for container in brand_containers:
    name = container.span.text
    names.append(name)
    
    logo = container.find('img', attrs = {'class': 'b-lazy'})
    logo_links.append(logo)

# %%
test_df = pd.DataFrame({'brand':names,
                        'logo_link':logo_links})

# %%
print(test_df.info())
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16688 entries, 0 to 16687
# Data columns (total 2 columns):
# brand        16688 non-null object
# logo_link    16688 non-null object
# dtypes: object(2)
# memory usage: 260.8+ KB
# None
#                                                    brand  \
# 0                                                  A2FLY
# 1                                      Aardvark Extracts
# 2                              Abattis Bioceuticals Corp
# 3                                      Ablis-Ablis Drink
# 4                                  Ablis Sparkling Green
# 5                                        Above Top Shelf
# 6                                Absolute Cannabis Seeds
# 7              Absolute Security and Personal Protection
# 8                                         Absolute Terps
# 9                                        AbsoluteXtracts
# 10                                            Absorb CBD
# 11                                              Abundant
# 12                                    Accannadations LLC
# 13                    Accelerated Growth Solutions (AGS)
# 14                                   Access Marijuana RX
# 15                                         Aces Extracts
# 16                                          ACESO Sprays
# 17                                          ACME Elixirs
# 18                                             AcquiFlow
# 19                                              AcroVape
# 20                                     ACT Laboratories
# 21                                            ACW Supply
# 22                                        Adam Equipment
# 23                                                 Adams
# 24     Adem and Leaves                               ...
# 25                                    Adherence Colorado
# 26                                                Adilas
# 27                           Advanced Canna Technologies
# 28                                     Advanced Extracts
# 29                                        Advanced Seeds
# ...                                                  ...
# 16658                                420 Real Properties
# 16659                                        420 Science
# 16660                              420 Security Advisors
# 16661                                           420 Time
# 16662                                          420 Vapor
# 16663                                            4blooms
# 16664                                    4Front Advisors
# 16665                                  4 Leaf Consulting
# 16666                                         4 LOVE OIL
# 16667                              4 Seasons Grow System
# 16668                                     5150 Wax Rolls
# 16669                                    5700 Consulting
# 16670                                    5-Hour High Co.
# 16671                                        64 Activate
# 16672                                     710 Errl Pharm
# 16673                                            710 KAN
# 16674                                        710 Kingpen
# 16675                                           710 Labs
# 16676                                   7 Leaf Marketing
# 16677                                    7 Points Oregon
# 16678                                                7vn
# 16679                                    7th Floor Vapes
# 16680                                   7 Rays Marketing
# 16681                                         7Greengold
# 16682                                   805 Buddha Bliss
# 16683                                       831 Organiks
# 16684                                         91 Supreme
# 16685                                 9 Planet Moonbites
# 16686                             dama Cannabis Products
# 16687                                        Élite Seeds
#
#                                                logo_link
# 0      <img alt="A2FLY" class="b-lazy" data-src="" da...
# 1      <img alt="Aardvark Extracts" class="b-lazy" da...
# 2      <img alt="Abattis Bioceuticals Corp" class="b-...
# 3      <img alt="Ablis-Ablis Drink" class="b-lazy" da...
# 4      <img alt="Ablis Sparkling Green" class="b-lazy...
# 5      <img alt="Above Top Shelf" class="b-lazy" data...
# 6      <img alt="Absolute Cannabis Seeds" class="b-la...
# 7      <img alt="Absolute Security and Personal Prote...
# 8      <img alt="Absolute Terps" class="b-lazy" data-...
# 9      <img alt="AbsoluteXtracts" class="b-lazy" data...
# 10     <img alt="Absorb CBD" class="b-lazy" data-src=...
# 11     <img alt="Abundant" class="b-lazy" data-src=""...
# 12     <img alt="Accannadations LLC" class="b-lazy" d...
# 13     <img alt="Accelerated Growth Solutions (AGS)" ...
# 14     <img alt="Access Marijuana RX" class="b-lazy" ...
# 15     <img alt="Aces Extracts" class="b-lazy" data-s...
# 16     <img alt="ACESO Sprays" class="b-lazy" data-sr...
# 17     <img alt="ACME Elixirs" class="b-lazy" data-sr...
# 18     <img alt="AcquiFlow" class="b-lazy" data-src="...
# 19     <img alt="AcroVape" class="b-lazy" data-src="h...
# 20     <img alt="ACT Laboratories " class="b-lazy" da...
# 21     <img alt="ACW Supply" class="b-lazy" data-src=...
# 22     <img alt="Adam Equipment" class="b-lazy" data-...
# 23     <img alt="Adams" class="b-lazy" data-src="" da...
# 24     <img alt="Adem and Leaves                     ...
# 25     <img alt="Adherence Colorado" class="b-lazy" d...
# 26     <img alt="Adilas" class="b-lazy" data-src="htt...
# 27     <img alt="Advanced Canna Technologies" class="...
# 28     <img alt="Advanced Extracts" class="b-lazy" da...
# 29     <img alt="Advanced Seeds" class="b-lazy" data-...
# ...                                                  ...
# 16658  <img alt="420 Real Properties" class="b-lazy" ...
# 16659  <img alt="420 Science" class="b-lazy" data-src...
# 16660  <img alt="420 Security Advisors" class="b-lazy...
# 16661  <img alt="420 Time" class="b-lazy" data-src=""...
# 16662  <img alt="420 Vapor" class="b-lazy" data-src="...
# 16663  <img alt="4blooms" class="b-lazy" data-src="ht...
# 16664  <img alt="4Front Advisors" class="b-lazy" data...
# 16665  <img alt="4 Leaf Consulting" class="b-lazy" da...
# 16666  <img alt="4 LOVE OIL" class="b-lazy" data-src=...
# 16667  <img alt="4 Seasons Grow System" class="b-lazy...
# 16668  <img alt="5150 Wax Rolls" class="b-lazy" data-...
# 16669  <img alt="5700 Consulting" class="b-lazy" data...
# 16670  <img alt="5-Hour High Co." class="b-lazy" data...
# 16671  <img alt="64 Activate" class="b-lazy" data-src...
# 16672  <img alt="710 Errl Pharm" class="b-lazy" data-...
# 16673  <img alt="710 KAN" class="b-lazy" data-src="ht...
# 16674  <img alt="710 Kingpen" class="b-lazy" data-src...
# 16675  <img alt="710 Labs" class="b-lazy" data-src="h...
# 16676  <img alt="7 Leaf Marketing" class="b-lazy" dat...
# 16677  <img alt="7 Points Oregon" class="b-lazy" data...
# 16678  <img alt="7vn" class="b-lazy" data-src="https:...
# 16679  <img alt="7th Floor Vapes" class="b-lazy" data...
# 16680  <img alt="7 Rays Marketing" class="b-lazy" dat...
# 16681  <img alt="7Greengold" class="b-lazy" data-src=...
# 16682  <img alt="805 Buddha Bliss" class="b-lazy" dat...
# 16683  <img alt="831 Organiks" class="b-lazy" data-sr...
# 16684  <img alt="91 Supreme" class="b-lazy" data-src=...
# 16685  <img alt="9 Planet Moonbites" class="b-lazy" d...
# 16686  <img alt=" dama Cannabis Products" class="b-la...
# 16687  <img alt="Élite Seeds" class="b-lazy" data-src...
#
# [16688 rows x 2 columns]
